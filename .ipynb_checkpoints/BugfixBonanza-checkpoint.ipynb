# %%
import pandas as pd

# %%
# Create a reference to the CSV and import it into a Pandas DataFrame
##no import pandas as pd
csv_path = "./EclipseBugs.csv"
eclipse_df = pd.read_csv(csv_path)
eclipse_df.head()
# Out:
#    Bug\nID Product Component Assignee    Status Resolution  \
# 0     3638     JDT        UI  aeschli  VERIFIED      FIXED
# 1     3854     JDT        UI  aeschli  VERIFIED      FIXED
# 2     4188     JDT        UI  aeschli  VERIFIED      FIXED
# 3     5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 4     5820     JDT        UI  aeschli  VERIFIED      FIXED
#
#                                              Summary           Changed  \
# 0  Package Viewer: order resource folders before ...    1/17/2002 7:28
# 1             Wrong execution's classpath. (1GEY0W0)    1/18/2002 4:02
# 2                     type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 3  Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 4    Close all editors brings up hierarchy of object  11/20/2001 16:22
#
#   Assignee\nReal\nName Classification  ... Number of\nComments  \
# 0   Martin Aeschlimann        Eclipse  ...                   3
# 1   Martin Aeschlimann        Eclipse  ...                   5
# 2   Martin Aeschlimann        Eclipse  ...                   3
# 3   Martin Aeschlimann        Eclipse  ...                  10
# 4   Martin Aeschlimann        Eclipse  ...                   5
#
#              Opened            OS Priority       Reporter  \
# 0  10/10/2001 22:58    Windows NT       P1        aeschli
# 1  10/10/2001 23:01    Windows NT       P1    david_audel
# 2  10/10/2001 23:07  Windows 2000       P1    erich_gamma
# 3  10/19/2001 13:41  Windows 2000       P1  darin.eclipse
# 4  11/12/2001 18:18  Windows 2000       P1   jed.anderson
#
#   Reporter\nReal\nName Severity Target\nMilestone Version Votes
# 0   Martin Aeschlimann    major               ---       2     0
# 1          David Audel   normal               ---       2     0
# 2          Erich Gamma   normal               ---       2     0
# 3         Darin Wright   normal               ---       2     0
# 4         Jed Anderson   normal               ---       2     0
#
# [5 rows x 21 columns]

# %%
##First see the columns
eclipse_df.columns
# Out:
# Index(['Bug\nID', 'Product', 'Component', 'Assignee', 'Status', 'Resolution',
#        'Summary', 'Changed', 'Assignee\nReal\nName', 'Classification',
#        'Hardware', 'Number of\nComments', 'Opened', 'OS', 'Priority',
#        'Reporter', 'Reporter\nReal\nName', 'Severity', 'Target\nMilestone',
#        'Version', 'Votes'],
#       dtype='object')

# %%
# Finding the average number of comments per bug
#print(eclipse_df["Number of\nComments"])
average_comments = eclipse_df.loc[eclipse_df["Number of\nComments"]]
average_comments
# Out:
#     Bug\nID Product Component Assignee    Status Resolution  \
# 3      5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# 3      5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 10    10929     JDT        UI  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# 2      4188     JDT        UI  aeschli  VERIFIED      FIXED
# 2      4188     JDT        UI  aeschli  VERIFIED      FIXED
# 4      5820     JDT        UI  aeschli  VERIFIED      FIXED
# 4      5820     JDT        UI  aeschli  VERIFIED      FIXED
# 7      7966     JDT        UI  aeschli  VERIFIED      FIXED
# 6      7329     JDT        UI  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# 14    43518     JDT        UI  aeschli  VERIFIED      FIXED
# 9      8280     JDT        UI  aeschli  VERIFIED      FIXED
# 15    44425     JDT        UI  aeschli  VERIFIED      FIXED
# 2      4188     JDT        UI  aeschli  VERIFIED      FIXED
# 2      4188     JDT        UI  aeschli  VERIFIED      FIXED
# 2      4188     JDT        UI  aeschli  VERIFIED      FIXED
# 3      5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# 6      7329     JDT        UI  aeschli  VERIFIED      FIXED
# 3      5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 4      5820     JDT        UI  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# 8      8224     JDT        UI  aeschli  VERIFIED      FIXED
# 8      8224     JDT        UI  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# ..      ...     ...       ...      ...       ...        ...
# 15    44425     JDT        UI  aeschli  VERIFIED      FIXED
# 6      7329     JDT        UI  aeschli  VERIFIED      FIXED
# 7      7966     JDT        UI  aeschli  VERIFIED      FIXED
# 14    43518     JDT        UI  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# 7      7966     JDT        UI  aeschli  VERIFIED      FIXED
# 4      5820     JDT        UI  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# 11    24911     JDT        UI  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
# 15    44425     JDT        UI  aeschli  VERIFIED      FIXED
# 17     6341     JDT        UI  akiezun  VERIFIED      FIXED
# 4      5820     JDT        UI  aeschli  VERIFIED      FIXED
# 19     7317     JDT        UI  akiezun  VERIFIED      FIXED
# 18     7046     JDT        UI  akiezun  VERIFIED      FIXED
# 11    24911     JDT        UI  aeschli  VERIFIED      FIXED
# 14    43518     JDT        UI  aeschli  VERIFIED      FIXED
# 3      5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 3      5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 4      5820     JDT        UI  aeschli  VERIFIED      FIXED
# 4      5820     JDT        UI  aeschli  VERIFIED      FIXED
# 3      5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 6      7329     JDT        UI  aeschli  VERIFIED      FIXED
# 13    32831     JDT        UI  aeschli  VERIFIED      FIXED
# 9      8280     JDT        UI  aeschli  VERIFIED      FIXED
# 4      5820     JDT        UI  aeschli  VERIFIED      FIXED
# 10    10929     JDT        UI  aeschli  VERIFIED      FIXED
# 17     6341     JDT        UI  akiezun  VERIFIED      FIXED
# 7      7966     JDT        UI  aeschli  VERIFIED      FIXED
# 5      6441     JDT        UI  aeschli  VERIFIED      FIXED
#
#                                               Summary           Changed  \
# 3   Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 3   Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 10           All types cache is flushed to frequently    3/20/2002 8:18
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 2                      type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 2                      type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 4     Close all editors brings up hierarchy of object  11/20/2001 16:22
# 4     Close all editors brings up hierarchy of object  11/20/2001 16:22
# 7        Class Creation Dialog generates syntax error    3/28/2002 5:43
# 6   Outline view: wrong spelling "Add JavDoc Comment"    1/15/2002 5:56
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 14  Stepping through session bean is very slow in ...   10/17/2003 5:27
# 9       Package view back/forward/up arrow hover help    2/13/2002 7:51
# 15  Illegal code in the code formatter preference ...   10/8/2003 17:44
# 2                      type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 2                      type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 2                      type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 3   Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 6   Outline view: wrong spelling "Add JavDoc Comment"    1/15/2002 5:56
# 3   Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 4     Close all editors brings up hierarchy of object  11/20/2001 16:22
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 8   Organize imports adds explicit import to wildc...    2/13/2002 8:38
# 8   Organize imports adds explicit import to wildc...    2/13/2002 8:38
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# ..                                                ...               ...
# 15  Illegal code in the code formatter preference ...   10/8/2003 17:44
# 6   Outline view: wrong spelling "Add JavDoc Comment"    1/15/2002 5:56
# 7        Class Creation Dialog generates syntax error    3/28/2002 5:43
# 14  Stepping through session bean is very slow in ...   10/17/2003 5:27
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 7        Class Creation Dialog generates syntax error    3/28/2002 5:43
# 4     Close all editors brings up hierarchy of object  11/20/2001 16:22
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 11  quick fix: NPE on 'change visibility to defaul...   11/14/2002 9:01
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 15  Illegal code in the code formatter preference ...   10/8/2003 17:44
# 17               NullPointerException from ReorgGroup    1/16/2002 2:31
# 4     Close all editors brings up hierarchy of object  11/20/2001 16:22
# 19                     ClassCastException during move    1/15/2002 5:53
# 18  NPE trying to show context menu on method in O...    1/15/2002 6:14
# 11  quick fix: NPE on 'change visibility to defaul...   11/14/2002 9:01
# 14  Stepping through session bean is very slow in ...   10/17/2003 5:27
# 3   Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 3   Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 4     Close all editors brings up hierarchy of object  11/20/2001 16:22
# 4     Close all editors brings up hierarchy of object  11/20/2001 16:22
# 3   Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 6   Outline view: wrong spelling "Add JavDoc Comment"    1/15/2002 5:56
# 13          NPE buildpaths.CPVariableElement.equals()   3/19/2003 10:43
# 9       Package view back/forward/up arrow hover help    2/13/2002 7:51
# 4     Close all editors brings up hierarchy of object  11/20/2001 16:22
# 10           All types cache is flushed to frequently    3/20/2002 8:18
# 17               NullPointerException from ReorgGroup    1/16/2002 2:31
# 7        Class Creation Dialog generates syntax error    3/28/2002 5:43
# 5       "Plugins containing only Jars" logis reverted    1/16/2002 2:58
#
#    Assignee\nReal\nName Classification  ... Number of\nComments  \
# 3    Martin Aeschlimann        Eclipse  ...                  10
# 5    Martin Aeschlimann        Eclipse  ...                   2
# 3    Martin Aeschlimann        Eclipse  ...                  10
# 10   Martin Aeschlimann        Eclipse  ...                   6
# 5    Martin Aeschlimann        Eclipse  ...                   2
# 2    Martin Aeschlimann        Eclipse  ...                   3
# 2    Martin Aeschlimann        Eclipse  ...                   3
# 4    Martin Aeschlimann        Eclipse  ...                   5
# 4    Martin Aeschlimann        Eclipse  ...                   5
# 7    Martin Aeschlimann        Eclipse  ...                   4
# 6    Martin Aeschlimann        Eclipse  ...                   2
# 5    Martin Aeschlimann        Eclipse  ...                   2
# 5    Martin Aeschlimann        Eclipse  ...                   2
# 5    Martin Aeschlimann        Eclipse  ...                   2
# 14   Martin Aeschlimann        Eclipse  ...                  14
# 9    Martin Aeschlimann        Eclipse  ...                   7
# 15   Martin Aeschlimann        Eclipse  ...                   9
# 2    Martin Aeschlimann        Eclipse  ...                   3
# 2    Martin Aeschlimann        Eclipse  ...                   3
# 2    Martin Aeschlimann        Eclipse  ...                   3
# 3    Martin Aeschlimann        Eclipse  ...                  10
# 5    Martin Aeschlimann        Eclipse  ...                   2
# 6    Martin Aeschlimann        Eclipse  ...                   2
# 3    Martin Aeschlimann        Eclipse  ...                  10
# 4    Martin Aeschlimann        Eclipse  ...                   5
# 5    Martin Aeschlimann        Eclipse  ...                   2
# 8    Martin Aeschlimann        Eclipse  ...                   4
# 8    Martin Aeschlimann        Eclipse  ...                   4
# 5    Martin Aeschlimann        Eclipse  ...                   2
# 5    Martin Aeschlimann        Eclipse  ...                   2
# ..                  ...            ...  ...                 ...
# 15   Martin Aeschlimann        Eclipse  ...                   9
# 6    Martin Aeschlimann        Eclipse  ...                   2
# 7    Martin Aeschlimann        Eclipse  ...                   4
# 14   Martin Aeschlimann        Eclipse  ...                  14
# 5    Martin Aeschlimann        Eclipse  ...                   2
# 7    Martin Aeschlimann        Eclipse  ...                   4
# 4    Martin Aeschlimann        Eclipse  ...                   5
# 5    Martin Aeschlimann        Eclipse  ...                   2
# 11   Martin Aeschlimann        Eclipse  ...                   5
# 5    Martin Aeschlimann        Eclipse  ...                   2
# 15   Martin Aeschlimann        Eclipse  ...                   9
# 17          Adam Kiezun        Eclipse  ...                   2
# 4    Martin Aeschlimann        Eclipse  ...                   5
# 19          Adam Kiezun        Eclipse  ...                   2
# 18          Adam Kiezun        Eclipse  ...                   2
# 11   Martin Aeschlimann        Eclipse  ...                   5
# 14   Martin Aeschlimann        Eclipse  ...                  14
# 3    Martin Aeschlimann        Eclipse  ...                  10
# 3    Martin Aeschlimann        Eclipse  ...                  10
# 4    Martin Aeschlimann        Eclipse  ...                   5
# 4    Martin Aeschlimann        Eclipse  ...                   5
# 3    Martin Aeschlimann        Eclipse  ...                  10
# 6    Martin Aeschlimann        Eclipse  ...                   2
# 13   Martin Aeschlimann        Eclipse  ...                   5
# 9    Martin Aeschlimann        Eclipse  ...                   7
# 4    Martin Aeschlimann        Eclipse  ...                   5
# 10   Martin Aeschlimann        Eclipse  ...                   6
# 17          Adam Kiezun        Eclipse  ...                   2
# 7    Martin Aeschlimann        Eclipse  ...                   4
# 5    Martin Aeschlimann        Eclipse  ...                   2
#
#               Opened            OS Priority         Reporter  \
# 3   10/19/2001 13:41  Windows 2000       P1    darin.eclipse
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 3   10/19/2001 13:41  Windows 2000       P1    darin.eclipse
# 10     3/7/2002 4:45  Windows 2000       P1      erich_gamma
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 2   10/10/2001 23:07  Windows 2000       P1      erich_gamma
# 2   10/10/2001 23:07  Windows 2000       P1      erich_gamma
# 4   11/12/2001 18:18  Windows 2000       P1     jed.anderson
# 4   11/12/2001 18:18  Windows 2000       P1     jed.anderson
# 7    1/21/2002 15:42  Windows 2000       P1      Tod_Creasey
# 6      1/8/2002 2:44    Windows NT       P1    daniel_megert
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 14   9/23/2003 11:52  Windows 2000       P1         stevenyj
# 9    1/23/2002 15:25  Windows 2000       P1       jeff_brown
# 15    10/8/2003 9:07  Windows 2000       P1  Olivier_Thomann
# 2   10/10/2001 23:07  Windows 2000       P1      erich_gamma
# 2   10/10/2001 23:07  Windows 2000       P1      erich_gamma
# 2   10/10/2001 23:07  Windows 2000       P1      erich_gamma
# 3   10/19/2001 13:41  Windows 2000       P1    darin.eclipse
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 6      1/8/2002 2:44    Windows NT       P1    daniel_megert
# 3   10/19/2001 13:41  Windows 2000       P1    darin.eclipse
# 4   11/12/2001 18:18  Windows 2000       P1     jed.anderson
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 8    1/23/2002 13:42         other       P1     knut_radloff
# 8    1/23/2002 13:42         other       P1     knut_radloff
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# ..               ...           ...      ...              ...
# 15    10/8/2003 9:07  Windows 2000       P1  Olivier_Thomann
# 6      1/8/2002 2:44    Windows NT       P1    daniel_megert
# 7    1/21/2002 15:42  Windows 2000       P1      Tod_Creasey
# 14   9/23/2003 11:52  Windows 2000       P1         stevenyj
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 7    1/21/2002 15:42  Windows 2000       P1      Tod_Creasey
# 4   11/12/2001 18:18  Windows 2000       P1     jed.anderson
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 11   10/17/2002 5:56  Windows 2000       P1          akiezun
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 15    10/8/2003 9:07  Windows 2000       P1  Olivier_Thomann
# 17   11/27/2001 5:58  Windows 2000       P1          aeschli
# 4   11/12/2001 18:18  Windows 2000       P1     jed.anderson
# 19    1/7/2002 14:05  Windows 2000       P1         fraenkel
# 18  12/18/2001 10:49         other       P1          eclipse
# 11   10/17/2002 5:56  Windows 2000       P1          akiezun
# 14   9/23/2003 11:52  Windows 2000       P1         stevenyj
# 3   10/19/2001 13:41  Windows 2000       P1    darin.eclipse
# 3   10/19/2001 13:41  Windows 2000       P1    darin.eclipse
# 4   11/12/2001 18:18  Windows 2000       P1     jed.anderson
# 4   11/12/2001 18:18  Windows 2000       P1     jed.anderson
# 3   10/19/2001 13:41  Windows 2000       P1    darin.eclipse
# 6      1/8/2002 2:44    Windows NT       P1    daniel_megert
# 13   2/24/2003 17:12   Linux-Motif       P1          airvine
# 9    1/23/2002 15:25  Windows 2000       P1       jeff_brown
# 4   11/12/2001 18:18  Windows 2000       P1     jed.anderson
# 10     3/7/2002 4:45  Windows 2000       P1      erich_gamma
# 17   11/27/2001 5:58  Windows 2000       P1          aeschli
# 7    1/21/2002 15:42  Windows 2000       P1      Tod_Creasey
# 5   11/29/2001 13:50  Windows 2000       P1      erich_gamma
#
#    Reporter\nReal\nName  Severity Target\nMilestone Version Votes
# 3          Darin Wright    normal               ---       2     0
# 5           Erich Gamma    normal               ---       2     0
# 3          Darin Wright    normal               ---       2     0
# 10          Erich Gamma    normal            2.0 M4       2     0
# 5           Erich Gamma    normal               ---       2     0
# 2           Erich Gamma    normal               ---       2     0
# 2           Erich Gamma    normal               ---       2     0
# 4          Jed Anderson    normal               ---       2     0
# 4          Jed Anderson    normal               ---       2     0
# 7           Tod Creasey    normal               ---       2     0
# 6           Dani Megert    normal               ---       2     0
# 5           Erich Gamma    normal               ---       2     0
# 5           Erich Gamma    normal               ---       2     0
# 5           Erich Gamma    normal               ---       2     0
# 14           Steven Jin  critical             2.1.2   2.1.1     0
# 9            Jeff Brown    normal               ---       2     0
# 15      Olivier Thomann   blocker            3.0 M4       3     0
# 2           Erich Gamma    normal               ---       2     0
# 2           Erich Gamma    normal               ---       2     0
# 2           Erich Gamma    normal               ---       2     0
# 3          Darin Wright    normal               ---       2     0
# 5           Erich Gamma    normal               ---       2     0
# 6           Dani Megert    normal               ---       2     0
# 3          Darin Wright    normal               ---       2     0
# 4          Jed Anderson    normal               ---       2     0
# 5           Erich Gamma    normal               ---       2     0
# 8          Knut Radloff    normal               ---       2     0
# 8          Knut Radloff    normal               ---       2     0
# 5           Erich Gamma    normal               ---       2     0
# 5           Erich Gamma    normal               ---       2     0
# ..                  ...       ...               ...     ...   ...
# 15      Olivier Thomann   blocker            3.0 M4       3     0
# 6           Dani Megert    normal               ---       2     0
# 7           Tod Creasey    normal               ---       2     0
# 14           Steven Jin  critical             2.1.2   2.1.1     0
# 5           Erich Gamma    normal               ---       2     0
# 7           Tod Creasey    normal               ---       2     0
# 4          Jed Anderson    normal               ---       2     0
# 5           Erich Gamma    normal               ---       2     0
# 11          Adam Kiezun     major            2.1 M3       2     0
# 5           Erich Gamma    normal               ---       2     0
# 15      Olivier Thomann   blocker            3.0 M4       3     0
# 17   Martin Aeschlimann    normal               ---       2     0
# 4          Jed Anderson    normal               ---       2     0
# 19     Michael Fraenkel    normal               ---       2     0
# 18      Joe Szurszewski    normal               ---       2     0
# 11          Adam Kiezun     major            2.1 M3       2     0
# 14           Steven Jin  critical             2.1.2   2.1.1     0
# 3          Darin Wright    normal               ---       2     0
# 3          Darin Wright    normal               ---       2     0
# 4          Jed Anderson    normal               ---       2     0
# 4          Jed Anderson    normal               ---       2     0
# 3          Darin Wright    normal               ---       2     0
# 6           Dani Megert    normal               ---       2     0
# 13        Andrew Irvine    normal           2.1 RC2     2.1     0
# 9            Jeff Brown    normal               ---       2     0
# 4          Jed Anderson    normal               ---       2     0
# 10          Erich Gamma    normal            2.0 M4       2     0
# 17   Martin Aeschlimann    normal               ---       2     0
# 7           Tod Creasey    normal               ---       2     0
# 5           Erich Gamma    normal               ---       2     0
#
# [10000 rows x 21 columns]

# %%
# Rename the "Component" column to "Component Bug Count"
eclipse_df = eclipse_df.rename(columns={'Component': 'Component Bug Count'})
eclipse_df.head()
# Out:
#    Bug\nID Product Component Bug Count Assignee    Status Resolution  \
# 0     3638     JDT                  UI  aeschli  VERIFIED      FIXED
# 1     3854     JDT                  UI  aeschli  VERIFIED      FIXED
# 2     4188     JDT                  UI  aeschli  VERIFIED      FIXED
# 3     5115     JDT               Debug  aeschli  VERIFIED      FIXED
# 4     5820     JDT                  UI  aeschli  VERIFIED      FIXED
#
#                                              Summary           Changed  \
# 0  Package Viewer: order resource folders before ...    1/17/2002 7:28
# 1             Wrong execution's classpath. (1GEY0W0)    1/18/2002 4:02
# 2                     type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 3  Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 4    Close all editors brings up hierarchy of object  11/20/2001 16:22
#
#   Assignee\nReal\nName Classification  ... Number of\nComments  \
# 0   Martin Aeschlimann        Eclipse  ...                   3
# 1   Martin Aeschlimann        Eclipse  ...                   5
# 2   Martin Aeschlimann        Eclipse  ...                   3
# 3   Martin Aeschlimann        Eclipse  ...                  10
# 4   Martin Aeschlimann        Eclipse  ...                   5
#
#              Opened            OS Priority       Reporter  \
# 0  10/10/2001 22:58    Windows NT       P1        aeschli
# 1  10/10/2001 23:01    Windows NT       P1    david_audel
# 2  10/10/2001 23:07  Windows 2000       P1    erich_gamma
# 3  10/19/2001 13:41  Windows 2000       P1  darin.eclipse
# 4  11/12/2001 18:18  Windows 2000       P1   jed.anderson
#
#   Reporter\nReal\nName Severity Target\nMilestone Version Votes
# 0   Martin Aeschlimann    major               ---       2     0
# 1          David Audel   normal               ---       2     0
# 2          Erich Gamma   normal               ---       2     0
# 3         Darin Wright   normal               ---       2     0
# 4         Jed Anderson   normal               ---       2     0
#
# [5 rows x 21 columns]

# %%
# Grouping the DataFrame by "Assignee"
assignee_group = eclipse_df.groupby("Assignee")

# Count how many of each component Assignees worked on and create DataFrame
assignee_work = pd.DataFrame(assignee_group["Component Bug Count"].value_counts())
assignee_work.head(20)
# Out:
#                                      Component Bug Count
# Assignee        Component Bug Count
# Aaron_Ferguson  UI                                    10
# Adam_Schlegel   UI                                     7
# ChrisAustin     User Assistance                        3
# Claude_Knaus    UI                                    31
#                 Text                                   7
# Curtis_Windatt  UI                                     3
#                 Debug                                  2
#                 API Tools                              1
# Darin_Swanson   Debug                                264
#                 Ant                                   33
# James_Moody     Team                                   2
# Karice_McIntyre UI                                     4
# Kevin_McGuire   Team                                   6
# Lars.Vogel      UI                                     3
# Michael_Rennie  Debug                                 34
#                 API Tools                              3
# Mike_Wilson     SWT                                    2
# Olivier_Thomann Core                                  23
#                 API Tools                              1
#                 APT                                    1

# %%
# Find the percentage of bugs overall fixed by each Assignee
total_bugs = assignee_group["Assignee"].count()
bugs_per_user = assignee_group["Assignee"].value_counts()

print(total_bugs)
print(bugs_per_user)
#user_bug_percent = pd.DataFrame((bugs_per_user/total_bugs)*100)
#user_bug_percent.head()
# Out:
# Assignee
# Aaron_Ferguson          10
# Adam_Schlegel            7
# ChrisAustin              3
# Claude_Knaus            38
# Curtis_Windatt           6
# Darin_Swanson          297
# James_Moody              2
# Karice_McIntyre          4
# Kevin_McGuire            6
# Lars.Vogel               3
# Michael_Rennie          37
# Mike_Wilson              2
# Olivier_Thomann         25
# Platform-UI-Inbox        4
# Randy_Giffen             8
# Silenio_Quarti          11
# Szymon.Brandys          16
# Tod_Creasey            459
# Vikas.Chandra            3
# a.aswani                 2
# abhishek.kishore         8
# abuzila                  1
# achilles-86              1
# achim.demelt             1
# aclement                 6
# aeschli                627
# aferrazz                 1
# agarcher                23
# ahunter.eclipse          3
# aiproulx                 1
#                       ...
# rafael.oliveira          1
# raksha.vasisht          16
# rthakkar                 5
# ryan_cooper             10
# sarika.sinha             1
# sasikanth.bharadwaj      1
# satyam.kandula           1
# serge                    1
# silvio_boehler           1
# simon_arsenault          6
# snorthov                 2
# sonia_dimitrov           2
# sravankumarl             1
# srikanth_sankaran        2
# stderr                   1
# stephan.herrmann         4
# susan                    9
# sxenos                  42
# szymon.ptaszkiewicz      2
# t.s.maeder              13
# teicher-bugzilla         3
# till_bay                21
# tobias_widmer           38
# tom.schindl              1
# tomasz.zarna             9
# unknown                  2
# valentam                30
# veronika_irvine          2
# wassim.melhem            4
# zhiyongl                 1
# Name: Assignee, Length: 205, dtype: int64
# Assignee             Assignee
# Aaron_Ferguson       Aaron_Ferguson          10
# Adam_Schlegel        Adam_Schlegel            7
# ChrisAustin          ChrisAustin              3
# Claude_Knaus         Claude_Knaus            38
# Curtis_Windatt       Curtis_Windatt           6
# Darin_Swanson        Darin_Swanson          297
# James_Moody          James_Moody              2
# Karice_McIntyre      Karice_McIntyre          4
# Kevin_McGuire        Kevin_McGuire            6
# Lars.Vogel           Lars.Vogel               3
# Michael_Rennie       Michael_Rennie          37
# Mike_Wilson          Mike_Wilson              2
# Olivier_Thomann      Olivier_Thomann         25
# Platform-UI-Inbox    Platform-UI-Inbox        4
# Randy_Giffen         Randy_Giffen             8
# Silenio_Quarti       Silenio_Quarti          11
# Szymon.Brandys       Szymon.Brandys          16
# Tod_Creasey          Tod_Creasey            459
# Vikas.Chandra        Vikas.Chandra            3
# a.aswani             a.aswani                 2
# abhishek.kishore     abhishek.kishore         8
# abuzila              abuzila                  1
# achilles-86          achilles-86              1
# achim.demelt         achim.demelt             1
# aclement             aclement                 6
# aeschli              aeschli                627
# aferrazz             aferrazz                 1
# agarcher             agarcher                23
# ahunter.eclipse      ahunter.eclipse          3
# aiproulx             aiproulx                 1
#                                            ...
# rafael.oliveira      rafael.oliveira          1
# raksha.vasisht       raksha.vasisht          16
# rthakkar             rthakkar                 5
# ryan_cooper          ryan_cooper             10
# sarika.sinha         sarika.sinha             1
# sasikanth.bharadwaj  sasikanth.bharadwaj      1
# satyam.kandula       satyam.kandula           1
# serge                serge                    1
# silvio_boehler       silvio_boehler           1
# simon_arsenault      simon_arsenault          6
# snorthov             snorthov                 2
# sonia_dimitrov       sonia_dimitrov           2
# sravankumarl         sravankumarl             1
# srikanth_sankaran    srikanth_sankaran        2
# stderr               stderr                   1
# stephan.herrmann     stephan.herrmann         4
# susan                susan                    9
# sxenos               sxenos                  42
# szymon.ptaszkiewicz  szymon.ptaszkiewicz      2
# t.s.maeder           t.s.maeder              13
# teicher-bugzilla     teicher-bugzilla         3
# till_bay             till_bay                21
# tobias_widmer        tobias_widmer           38
# tom.schindl          tom.schindl              1
# tomasz.zarna         tomasz.zarna             9
# unknown              unknown                  2
# valentam             valentam                30
# veronika_irvine      veronika_irvine          2
# wassim.melhem        wassim.melhem            4
# zhiyongl             zhiyongl                 1
# Name: Assignee, Length: 205, dtype: int64

# %%
# Merge the "Percent of Total Bugs Assigned" into the DataFrame
assignee_work = assignee_work.merge(user_bug_percent, on="Assignee")

# Remove the extra columns
assignee_work = assignee_work[[
    "Assignee", "Percent of Total Bugs", "Component", "Component Bug Count"]]
assignee_work.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-1100f48f945f> in <module>
#       1 # Merge the "Percent of Total Bugs Assigned" into the DataFrame
# ----> 2 assignee_work = assignee_work.merge(user_bug_percent, on="Assignee")
#       3
#       4 # Remove the extra columns
#       5 assignee_work = assignee_work[[
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     831                         if rk is not None:
#     832                             right_keys.append(
# --> 833                                 right._get_label_or_level_values(rk))
#     834                         else:
#     835                             # work-around for merge_asof(right_index=True)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1699
#    1700         if self._is_label_reference(key, axis=axis):
# -> 1701             self._check_label_or_level_ambiguity(key, axis=axis)
#    1702             values = self.xs(key, axis=other_axes[0])._values
#    1703         elif self._is_level_reference(key, axis=axis):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _check_label_or_level_ambiguity(self, key, axis)
#    1653                             label_article=label_article,
#    1654                             label_type=label_type)
# -> 1655             raise ValueError(msg)
#    1656
#    1657     def _get_label_or_level_values(self, key, axis=0):
#
# ValueError: 'Assignee' is both an index level and a column label, which is ambiguous.
