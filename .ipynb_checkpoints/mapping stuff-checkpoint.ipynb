# %%
import pandas as pd

# %%
#get the file path
file = "./KickstarterData.csv"

# %%
#display file
df_KD = pd.read_csv(file)
df_KD.head(60)
# Out:
#             id                                              photo  \
# 0   1645666704  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1    874638240  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2    247074984  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3   1941196813  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 4    421961595  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 5    319700919  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 6    177484975  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 7    601170861  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 8   1523103519  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 9    477372304  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 10  1302269979  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 11  1491852635  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 12  1440808021  {"small":"https://ksr-ugc.imgix.net/assets/012...
# ...

# %%
for col in df_KD.columns:
    print(col)
# Out:
# id
# photo
# name
# blurb
# goal
# pledged
# state
# slug
# disable_communication
# country
# currency
# currency_symbol
# currency_trailing_code
# deadline
# state_changed_at
# created_at
# launched_at
# staff_pick
# is_starrable
# backers_count
# static_usd_rate
# usd_pledged
# creator
# location
# category
# profile
# spotlight
# urls
# source_url
# friends
# is_starred
# is_backing
# permissions

# %%
KD_df = df_KD[["name", "goal", "pledged", "state", "country", "staff_pick", "backers_count", "spotlight",]]
KD_df.head()
# Out:
#                                                 name    goal  pledged  \
# 0  The Class Act Players Theatre Company Presents...  1500.0   2925.0
# 1  MR INCREDIBLE by Camilla Whitehill - VAULT Fes...  2500.0   2936.0
# 2                                                RUN  1000.0   1200.0
# 3  9th International Meeting of Youth Theatre sap...  2000.0   2135.0
# 4                        Get Conti to the Ed Fringe!  1000.0   1250.0
#
#         state country  staff_pick  backers_count  spotlight
# 0  successful      US       False             17       True
# 1  successful      GB        True             15       True
# 2  successful      GB       False             30       True
# 3  successful      IT       False             24       True
# 4  successful      GB       False             28       True

# %%
KD_df = KD_df.loc[(KD_df["pledged"] > 0)]
KD_df.head()
# Out:
#                                                 name    goal  pledged  \
# 0  The Class Act Players Theatre Company Presents...  1500.0   2925.0
# 1  MR INCREDIBLE by Camilla Whitehill - VAULT Fes...  2500.0   2936.0
# 2                                                RUN  1000.0   1200.0
# 3  9th International Meeting of Youth Theatre sap...  2000.0   2135.0
# 4                        Get Conti to the Ed Fringe!  1000.0   1250.0
#
#         state country  staff_pick  backers_count  spotlight
# 0  successful      US       False             17       True
# 1  successful      GB        True             15       True
# 2  successful      GB       False             30       True
# 3  successful      IT       False             24       True
# 4  successful      GB       False             28       True

# %%
KD_us_df = KD_df.loc[(KD_df["country"] == "US")]
KD_us_df.head()
# Out:
#                                                  name     goal  pledged  \
# 0   The Class Act Players Theatre Company Presents...   1500.0   2925.0
# 8                             Forefront Festival 2015   7200.0   7230.0
# 11                              Hamlet the Hip-Hopera   9747.0  10103.0
# 14                                          Pride Con  15000.0  15110.0
# 15      En Garde Arts Emerging Artists Festival BOSSS  10000.0  10306.0
#
#          state country  staff_pick  backers_count  spotlight
# 0   successful      US       False             17       True
# 8   successful      US       False             68       True
# 11  successful      US        True            132       True
# 14  successful      US       False             60       True
# 15  successful      US        True             80       True

# %%
average_donation = KD_us_df["pledged"]/KD_us_df["backers_count"]
average_donation
# Out:
# 0       172.058824
# 8       106.323529
# 11       76.537879
# 14      251.833333
# 15      128.825000
# 17       66.578947
# 19       76.470588
# 20       61.666667
# 31      105.000000
# 32      143.181818
# 33       69.117647
# 39      167.117647
# 42       62.714286
# 43       81.975000
# 44       54.241935
# 45       65.216667
# 46       42.036765
# 47       99.131579
# 48       54.347826
# 50       93.147059
# 52       37.016129
# 54       90.130952
# 59      119.047619
# 64      229.772727
# 67       59.701493
# 73       27.133333
# 74       50.500000
# 75      106.358491
# 77       54.961165
# 79       44.426230
#            ...
# 4076    107.002075
# 4077     50.981818
# 4078     52.551020
# 4080     47.878788
# 4081    150.416667
# 4082     96.666667
# 4083    133.333333
# 4084     51.222222
# 4086     93.813433
# 4087    176.086957
# 4088     45.478261
# 4091     97.916667
# 4092     77.186047
# 4093     87.961538
# 4094    122.536585
# 4095     98.200000
# ...

# %%
KD_us_df["average_donation"] = KD_us_df["pledged"]/KD_us_df["backers_count"]
KD_us_df.head()
# Out:
# C:\Users\hsala\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                                  name     goal  pledged  \
# 0   The Class Act Players Theatre Company Presents...   1500.0   2925.0
# 8                             Forefront Festival 2015   7200.0   7230.0
# 11                              Hamlet the Hip-Hopera   9747.0  10103.0
# 14                                          Pride Con  15000.0  15110.0
# 15      En Garde Arts Emerging Artists Festival BOSSS  10000.0  10306.0
#
#          state country  staff_pick  backers_count  spotlight  average_donation
# ...

# %%
KD_us_df["average_donation"] =
