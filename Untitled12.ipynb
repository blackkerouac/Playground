# %%
import pandas as pd
import numpy as np #imports

# %%
file = "./soccer2018Data.csv" #file path

# %%
df_original = pd.read_csv(file)
df_original.head(20) #display file
# Out:
#                  Name  Age Nationality  Overall  Potential  \
# 0   Cristiano Ronaldo   32    Portugal       94         94
# 1            L. Messi   30   Argentina       93         93
# 2              Neymar   25      Brazil       92         94
# 3           L. Suárez   30     Uruguay       92         92
# 4            M. Neuer   31     Germany       92         92
# 5      R. Lewandowski   28      Poland       91         91
# 6              De Gea   26       Spain       90         92
# 7           E. Hazard   26     Belgium       90         91
# 8            T. Kroos   27     Germany       90         90
# 9          G. Higuaín   29   Argentina       90         90
# 10       Sergio Ramos   31       Spain       90         90
# 11       K. De Bruyne   26     Belgium       89         92
# 12        T. Courtois   25     Belgium       89         92
# 13         A. Sánchez   28       Chile       89         89
# 14          L. Modrić   31     Croatia       89         89
# ...

# %%
df_original["Preferred Position"].unique()
# Out:
# array(['ST', 'RW', 'LW', 'GK', 'CDM', 'CB', 'RM', 'CM', 'LM', 'LB', 'CAM',
#        'RB', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
df_players = df_original[["Name", "Preferred Position", "Overall"]]
df_players.head()
# Out:
#                 Name Preferred Position  Overall
# 0  Cristiano Ronaldo                 ST       94
# 1           L. Messi                 RW       93
# 2             Neymar                 LW       92
# 3          L. Suárez                 ST       92
# 4           M. Neuer                 GK       92

# %%
the_best = df_players.sort_values("Overall", ascending = True)
the_best.head()
# Out:
#                Name Preferred Position  Overall
# 17980     L. Sackey                 ST       46
# 17973     T. Sawyer                 CM       46
# 17974     J. Keeble                 CB       46
# 17975  T. Käßemodel                 CM       46
# 17979  J. Lundstram                 CM       46

# %%
the_worst = the_best.loc[17980, :]
the_worst
# Out:
# Name                  L. Sackey
# Preferred Position           ST
# Overall                      46
# Name: 17980, dtype: object
